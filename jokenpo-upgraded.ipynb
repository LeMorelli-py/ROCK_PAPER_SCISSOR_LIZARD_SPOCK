# %%
from random import randint
itens = ('Pedra', 'Papel', 'Tesoura', 'Lagarto', 'Spock')
computador = randint(0, 4)
print(''' SUAS OPÇOES
[0] PEDRA
[1] PAPEL
[2] TESOURA
[3] LAGARTO
[4] SPOCK            ''')
jogador = int(input('Qual a sua jogada? '))
print(f'Computador jogou {itens[computador]}')
print(f'Jogador jogou {itens[jogador]}')
      
if computador == 0: #computador jogou PEDRA
      if jogador == 0: #Jogador: PEDRA
          print('EMPATE') 
      elif jogador == 1: #jogador: PAPEL
          print('Jogador ganhou! PAPEL COBRIU A PEDRA')
      elif jogador == 2: # jogador: TESOURA
          print('Computador ganhou!! PEDRA QUEBROU A TESOURA')
      elif jogador == 3: #jogador: LAGARTO
          print('Computador ganhou! PEDRA ESMAGOU O LAGARTO')
      elif jogador == 4: #jogador: SPOCK
          print('Jogador ganhou! SPOCK VAPORIZOU A PEDRA')
      else:
          print('JOGADA INVALIDA!!')

elif computador == 1: #computador jogou PAPEL
      if jogador == 0: #Jogador: PEDRA
          print('Computador ganhou! A PAPEL COBRIU A PEDRA')
      elif jogador == 1: #jogador: PAPEL
          print('EMPATE')
      elif jogador == 2: # jogador: TESOURA
          print('Jogador ganhou! TESOURA CORTOU O PAPEL')
      elif jogador == 3: #jogador: LAGARTO
          print('Jogador ganhou! LAGARTO COMEU O PAPEL')
      elif jogador == 4: #jogador: SPOCK
          print('Computador ganhou! PAPEL DESAPROVOU O SPOCK')
      else:
          print('JOGADA INVALIDA!!')

elif computador == 2: #computador jogou TESOURA
      if jogador == 0: #Jogador: PEDRA
          print('Jogador ganhou! PEDRA QUEBROU A TESOURA')
      elif jogador == 1: #jogador: PAPEL
          print('Computador ganhou! TESOURA CORTOU O PAPEL')
      elif jogador == 2: # jogador: TESOURA
          print('EMPATE')
      elif jogador == 3: #jogador: LAGARTO
          print('Computador ganhou! TESOURA DECAPITOU O LAGARTO')
      elif jogador == 4: #jogador: SPOCK
          print('Jogador ganhou! SPOCK DESTRUIU A TESOURA')
      else:
          print('JOGADA INVALIDA!!')

elif computador == 3: #computador jogou LAGARTO
      if jogador == 0: #Jogador: PEDRA
          print('Jogador ganhou! PEDRA ESMAGOU O LAGARTO')
      elif jogador == 1: #jogador: PAPEL
          print('Computador ganhou! LAGARDO COMEU O PAPEL')
      elif jogador == 2: # jogador: TESOURA
          print('Jogador Ganhou! TESOURA DECAPITOU O LAGARTO')
      elif jogador == 3: #jogador: LAGARTO
          print('EMPATE')
      elif jogador == 4: #jogador: SPOCK
          print('Computador ganhou! LAGARTO ENVENENOU O SPOCK')
      else:
          print('JOGADA INVALIDA!!')

elif computador == 4: #computador jogou SPOCK
      if jogador == 0: #Jogador: PEDRA
          print('Computador ganhou! SPOCK VAPORIZOU A PEDRA')
      elif jogador == 1: #jogador: PAPEL
          print('Jogador ganhou! PAPEL DESAPROVOU O SPOCK')
      elif jogador == 2: # jogador: TESOURA
          print('Computador Ganhou! SPOCK DESTRUIU A TESOURA')
      elif jogador == 3: #jogador: LAGARTO
          print('Jogador ganhou! LAGARTO ENVENENOU O SPOCK')
      elif jogador == 4: #jogador: SPOCK
          print('EMPATE')
      else:
          print('JOGADA INVALIDA!!')
# Out:
#  SUAS OPÇOES
# [0] PEDRA
# [1] PAPEL
# [2] TESOURA
# [3] LAGARTO
# [4] SPOCK
# Computador jogou Papel
# Jogador jogou Lagarto
# Jogador ganhou! LAGARTO COMEU O PAPEL
